# %%
import uuid
import json
import random
import os
import sys
from time import sleep
from datetime import datetime
import requests as rt
import numpy as np


from kafka import KafkaProducer, KafkaConsumer


from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException,ElementNotInteractableException, ElementClickInterceptedException


import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker

# %%
def get_browser(driver_path=r'chromedriver/chromedriver.exe', headless=False):
    options = webdriver.ChromeOptions()
    if headless:
        options.add_argument('headless')
    options.add_argument('window-size=1200x600')
    browser = webdriver.Chrome(driver_path, options=options)
    return browser

# %%
def get_vacancies_on_page(browser):    
    #close pop-up window with suggested region (if present)
    try:
        browser.find_element_by_class_name('bloko-icon_cancel').click()
    except (NoSuchElementException, ElementNotInteractableException):
        pass
    
    vacancy_cards = browser.find_elements_by_class_name('vacancy-serp-item ')
    
    return vacancy_cards

# %%
def get_vacancy_info(card, browser, keyword, verbose=True):
    
    try:
        card.find_element_by_class_name('vacancy-serp-item__info')\
            .find_element_by_tag_name('a')\
            .send_keys(Keys.CONTROL + Keys.RETURN) #open new tab in Chrome

        sleep(2) #let it fully load
        #go to the last opened tab
        browser.switch_to.window(browser.window_handles[-1])
        
        basic_info = False
        while not basic_info:
            try:
                vacancy_title = browser.find_element_by_xpath('//div[@class="vacancy-title"]//h1').text
                company_name = browser.find_element_by_xpath('//a[@class="vacancy-company-name"]').text
                company_href_hh = browser.find_element_by_xpath('//a[@class="vacancy-company-name"]').get_attribute('href')
                publish_time = browser.find_element_by_xpath('//p[@class="vacancy-creation-time"]').text
                basic_info = True
            except:
                sleep(3)
        
        if verbose:
            print("Title: ", vacancy_title )
            print("Company: ", company_name )
            print("Company link: ", company_href_hh )
            print("Publish time: ", publish_time )

        try:
            salary = browser.find_element_by_xpath('//div[@class="vacancy-title"]//p[@class="vacancy-salary"]').text
        except NoSuchElementException :
            salary = 'не указано'
            
        
        try:
            emp_mode = browser.find_element_by_xpath('//p[@data-qa="vacancy-view-employment-mode"]').text
        except NoSuchElementException :
            emp_mode = 'не указано'
        finally:
            emp_mode = emp_mode.strip().replace('\n', ' ')
        
            
        try:
            exp = browser.find_element_by_xpath('//span[@data-qa="vacancy-experience"]').text
        except NoSuchElementException :
            exp = 'не указано'
        finally: 
            exp = exp.strip().replace('\n', ' ')
        
        try:
            company_address = browser.find_element_by_xpath('//span[@data-qa="vacancy-view-raw-address"]').text
        except NoSuchElementException:
            company_address = 'не указано'
            
        try:
            vacancy_description = browser.find_element_by_xpath('//div[@data-qa="vacancy-description"]').text
        except NoSuchElementException:
            vacancy_description = 'не указано'
        finally:
            vacancy_description = vacancy_description.replace('\n', ' ')
            
        try:
            vacancy_tags = browser.find_element_by_xpath('//div[@class="bloko-tag-list"]').text
        except NoSuchElementException:
            vacancy_tags = 'не указано'
        finally:
            vacancy_tags = vacancy_tags.replace('\n', ', ')
            
        if verbose:    
            print("Salary: ", salary )
            print("Company address: ", company_address )
            print('Experience: ', exp)
            print('Employment mode: ', emp_mode)
            print("Vacancy description: ", vacancy_description[:50] )
            print("Vacancy tags: ", vacancy_tags)

        browser.close() #close tab
        browser.switch_to.window(browser.window_handles[0]) #switch to the first tab
        
        dt = str(datetime.now())
        
        vacancy_info = {'dt': dt,
                        'keyword': keyword,
                        'vacancy_title': vacancy_title,
                       'vacancy_salary': salary,
                       'vacancy_tags': vacancy_tags,
                       'vacancy_description': vacancy_description,
                        'vacancy_experience' : exp,
                        'employment_mode': emp_mode,
                       'company_name':company_name,
                       'company_link':company_href_hh,
                       'company_address':company_address,
                       'publish_place_and_time':publish_time}
        
        return vacancy_info
            

    except Exception as ex:
        print('Exeption while scraping info!')
        print(str(ex))
        return None

# %%
def insert_data(data, engine, table_name='HH_vacancies', schema='webscraping', verbose=True): 
    metadata = sa.MetaData(bind=engine)
    table = sa.Table(table_name, metadata, autoload=True, schema=schema)
    con = engine.connect()
    try:
        con.execute(table.insert().values(data))
        if verbose:
            print('Data inserted into table {}'.format(table_name))
    except Exception as ex:
        print('Exception while inserting data!')
        print(str(ex))
    finally:    
        con.close()

# %%
def scrape_HH(browser, keyword='Python', pages2scrape=3, table2save='HH_vacancies', verbose=True):
    url = f'https://hh.ru/search/vacancy?area=1&fromSearchLine=true&st=searchVacancy&text={keyword}&from=suggest_post'
    browser.get(url)
    while pages2scrape > 0:
        vacancy_cards = get_vacancies_on_page(browser=browser)
        for card in vacancy_cards:
            vacancy_info = get_vacancy_info(card, browser=browser, keyword=keyword, verbose=verbose)
            insert_data(data=vacancy_info, engine=engine, table_name=table2save)
            if verbose:
                print('Inserted row')
        try:
            #click to the "Next" button to load other vacancies
            browser.find_element_by_xpath('//a[@data-qa="pager-next"]').click()
            print('Go to the next page')
        except (NoSuchElementException, ElementNotInteractableException):
            browser.close()
            break
        finally:
            pages2scrape -= 1

# %%
def send_message(producer, topic_name, msg):
    msg_id = str(uuid.uuid4())
    msg['uid'] = msg_id 
    producer.send(topic_name, msg)
    producer.flush()    
    print(f'PRODUCER: Sent message with id: {msg_id}')
    
    sleep(0.5)

# %%
scrape_HH(browser, keyword='Kafka', pages2scrape=4, verbose=False)
# Out:
# Go to the next page
# Go to the next page
# Go to the next page
# Go to the next page

# %%
# browser.close()

# browser.quit()

# %%
def scrape_HH_to_kafka(browser, producer, keyword='Python', pages2scrape=3, topic_name='parsed-jobs', verbose=True):
    url = f'https://hh.ru/search/vacancy?area=1&fromSearchLine=true&st=searchVacancy&text={keyword}&from=suggest_post'
    browser.get(url)
    while pages2scrape > 0:
        vacancy_cards = get_vacancies_on_page(browser=browser)
        for card in vacancy_cards:
            vacancy_info = get_vacancy_info(card, browser=browser, keyword=keyword, verbose=verbose)           
            
            #sending scraping results to kafka
            send_message(producer, topic_name=topic_name, msg=vacancy_info)
            
            if verbose:
                print('Inserted row')
        try:
            #click to the "Next" button to load other vacancies
            browser.find_element_by_xpath('//a[@data-qa="pager-next"]').click()
            print('Go to the next page')
        except (NoSuchElementException, ElementNotInteractableException):
            break
        finally:
            pages2scrape -= 1
            
    browser.quit()
    producer.close()

# %%
KAFKA_HOST = 'localhost:9092'

# %%
producer = KafkaProducer(bootstrap_servers=KAFKA_HOST,
                        value_serializer=lambda x: json.dumps(x).encode('utf-8'))

# %%
browser = get_browser(driver_path=r'chromedriver/chromedriver.exe', headless=False)

# %%
scrape_HH_to_kafka(browser, producer, keyword='Golang', pages2scrape=1, topic_name='parsed-jobs', verbose=False)
# Out:
# PRODUCER: Sent message with id: 0a66d7df-a9da-4607-8ef5-33a55f640c71
# PRODUCER: Sent message with id: e1279143-473f-4f0e-b9dc-460026e8dd03
# PRODUCER: Sent message with id: 0c67088a-f05e-443c-bbc8-a2733762c2d0
# PRODUCER: Sent message with id: c98c11dd-05a9-46f1-b0e1-6624be200238
# PRODUCER: Sent message with id: c4d5ddf0-8b76-4388-94ee-f019845739c7
# PRODUCER: Sent message with id: b19f1248-70b0-4d7f-951d-0a5e619e117f
# PRODUCER: Sent message with id: eb890b31-c369-48a8-933d-6e163128f6af
# PRODUCER: Sent message with id: 911caead-c505-4782-8958-375a7d6c195a
# PRODUCER: Sent message with id: 49a9d9af-c096-4f80-ad31-bedc1f8dc0a1
# PRODUCER: Sent message with id: e6a5b7fd-5a93-4150-80a1-21898d817a27
# PRODUCER: Sent message with id: e4f998c3-ac97-4b91-9eb3-480430d023e8
# PRODUCER: Sent message with id: e038fadc-59e9-4ea7-969e-728117ba4733
# PRODUCER: Sent message with id: 3c63aa96-b7ca-4020-b3b1-1186b1519850
# PRODUCER: Sent message with id: 64783164-024f-47fd-921a-836f17d9ef96
# PRODUCER: Sent message with id: 49b865e9-8eed-4773-8209-5ef77403dbf8
# PRODUCER: Sent message with id: 7b55490a-129f-4b4d-a7bf-331bd4c36cdd
# PRODUCER: Sent message with id: 08b9b7cf-37ca-4dca-9387-40f5a3748c19
# PRODUCER: Sent message with id: 1526e24f-70ca-438a-93f1-20f436806452
# PRODUCER: Sent message with id: d5c3372b-ba5e-477d-9b0c-936c1b09e167
# PRODUCER: Sent message with id: 5387129e-dfce-45e8-a50d-8f80adce8169
# PRODUCER: Sent message with id: f04e2c96-0bd3-45a4-a627-708ab9fce53c
# PRODUCER: Sent message with id: 61b7cba1-7f8f-44c4-9efe-0b9028a69657
# PRODUCER: Sent message with id: fb6c21b1-7185-45ba-93cc-04320d78d50f
# PRODUCER: Sent message with id: 258017eb-73e7-44db-afe8-4a0cbc04f724
# PRODUCER: Sent message with id: 5b284540-741e-4bb2-907c-a32775f43d25
# PRODUCER: Sent message with id: 7bc06542-d335-48c4-8485-b6db6a9b2d56
# PRODUCER: Sent message with id: 8b3437dc-b343-4445-8d8f-c99d8a95e771
# PRODUCER: Sent message with id: 682ac29e-61c2-471a-bfea-07678deda19d
# PRODUCER: Sent message with id: 39b2984a-272e-4a1f-ab36-297785cfc31e
# PRODUCER: Sent message with id: e022b39d-4c34-40c1-81a8-213cf51c357c
# PRODUCER: Sent message with id: 2089cfed-6511-447f-9eff-7a7e7f8ea031
# PRODUCER: Sent message with id: c3ed0656-dfe5-4466-8eed-5651b490569f
# PRODUCER: Sent message with id: 0285f0c8-8074-476d-903c-5a3ba86eedd6
# PRODUCER: Sent message with id: 4fbac522-605e-4fc0-aefb-c6502016ba7a
# PRODUCER: Sent message with id: b40830dc-1028-49f2-85f6-f90ff1240452
# PRODUCER: Sent message with id: 9be8ef9d-f8f3-4d05-a5ef-813303dfae33
# PRODUCER: Sent message with id: b60dc3e2-722c-46f6-9faa-0d19ae14e916
# PRODUCER: Sent message with id: da628ca7-31ae-462e-876d-0244be0108db
# PRODUCER: Sent message with id: a6a253e0-32f8-4a5f-80aa-5d82cc0ff13b
# PRODUCER: Sent message with id: 5c1fc905-39c2-4b60-a076-8d27abf61d5d
# PRODUCER: Sent message with id: 85cf3fcd-2335-4681-99dd-a939306e9766
# PRODUCER: Sent message with id: 2bbb2565-6f46-4896-908b-2f17c37e85ca
# PRODUCER: Sent message with id: f604e68c-1bcb-4612-881c-c94135061449
# PRODUCER: Sent message with id: 482c6655-5d22-4d0e-9556-3619eefa685f
# PRODUCER: Sent message with id: 87dae318-d391-4b26-aac2-4f686b2e2d1a
# PRODUCER: Sent message with id: 3c76f905-63fc-43ad-bac9-5d489a07159b
# PRODUCER: Sent message with id: a3b7419e-89d0-437b-ba5f-596263106adb
# PRODUCER: Sent message with id: baac9d2e-2b0c-4cfc-b9f3-9b9938842d14
# PRODUCER: Sent message with id: 6b1bf494-0ce1-4a07-a5ad-12dad26a60af
# PRODUCER: Sent message with id: e56e7411-6d2e-4d94-a657-46578c5e2186
# Go to the next page

# %%
consumer = KafkaConsumer(
    'parsed-jobs', 
    bootstrap_servers=KAFKA_HOST,
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='my-group',
    value_deserializer=lambda x: json.loads(x.decode('utf-8')))

# %%
mysql_con = 'mysql+pymysql://python_user:123@127.0.0.1:3306/webscraping?charset=utf8mb4'
engine = sa.create_engine(mysql_con)

# %%
def consume_and_insert(consumer, engine, verbose=True):
    try:
        for msg in consumer:
            message = msg.value
            if verbose:
                print(f"CONSUMER: Consumed message with id: {message['uid']}!")
                
            insert_data(message, engine, table_name='HH_vacancies', schema='webscraping', verbose=verbose)
    except KeyboardInterrupt:
        consumer.close() 
        print("Closed consumer!")

# %%
consume_and_insert(consumer, engine, verbose=True)
# Out:
# Consumed message with id: 0a66d7df-a9da-4607-8ef5-33a55f640c71!
# Data inserted into table HH_vacancies
# Consumed message with id: e1279143-473f-4f0e-b9dc-460026e8dd03!
# Data inserted into table HH_vacancies
# Consumed message with id: 0c67088a-f05e-443c-bbc8-a2733762c2d0!
# Data inserted into table HH_vacancies
# Consumed message with id: c98c11dd-05a9-46f1-b0e1-6624be200238!
# Data inserted into table HH_vacancies
# Consumed message with id: c4d5ddf0-8b76-4388-94ee-f019845739c7!
# Data inserted into table HH_vacancies
# Consumed message with id: b19f1248-70b0-4d7f-951d-0a5e619e117f!
# Data inserted into table HH_vacancies
# Consumed message with id: eb890b31-c369-48a8-933d-6e163128f6af!
# Data inserted into table HH_vacancies
# Consumed message with id: 911caead-c505-4782-8958-375a7d6c195a!
# Data inserted into table HH_vacancies
# Consumed message with id: 49a9d9af-c096-4f80-ad31-bedc1f8dc0a1!
# Data inserted into table HH_vacancies
# Consumed message with id: e6a5b7fd-5a93-4150-80a1-21898d817a27!
# Data inserted into table HH_vacancies
# Consumed message with id: e4f998c3-ac97-4b91-9eb3-480430d023e8!
# Data inserted into table HH_vacancies
# Consumed message with id: e038fadc-59e9-4ea7-969e-728117ba4733!
# Data inserted into table HH_vacancies
# Consumed message with id: 3c63aa96-b7ca-4020-b3b1-1186b1519850!
# Data inserted into table HH_vacancies
# Consumed message with id: 64783164-024f-47fd-921a-836f17d9ef96!
# Data inserted into table HH_vacancies
# Consumed message with id: 49b865e9-8eed-4773-8209-5ef77403dbf8!
# Data inserted into table HH_vacancies
# Consumed message with id: 7b55490a-129f-4b4d-a7bf-331bd4c36cdd!
# Data inserted into table HH_vacancies
# Consumed message with id: 08b9b7cf-37ca-4dca-9387-40f5a3748c19!
# Data inserted into table HH_vacancies
# Consumed message with id: 1526e24f-70ca-438a-93f1-20f436806452!
# Data inserted into table HH_vacancies
# Consumed message with id: d5c3372b-ba5e-477d-9b0c-936c1b09e167!
# Data inserted into table HH_vacancies
# Consumed message with id: 5387129e-dfce-45e8-a50d-8f80adce8169!
# Data inserted into table HH_vacancies
# Consumed message with id: f04e2c96-0bd3-45a4-a627-708ab9fce53c!
# Data inserted into table HH_vacancies
# Consumed message with id: 61b7cba1-7f8f-44c4-9efe-0b9028a69657!
# Data inserted into table HH_vacancies
# Consumed message with id: fb6c21b1-7185-45ba-93cc-04320d78d50f!
# Data inserted into table HH_vacancies
# Consumed message with id: 258017eb-73e7-44db-afe8-4a0cbc04f724!
# Data inserted into table HH_vacancies
# Consumed message with id: 5b284540-741e-4bb2-907c-a32775f43d25!
# Data inserted into table HH_vacancies
# Consumed message with id: 7bc06542-d335-48c4-8485-b6db6a9b2d56!
# Data inserted into table HH_vacancies
# Consumed message with id: 8b3437dc-b343-4445-8d8f-c99d8a95e771!
# Data inserted into table HH_vacancies
# Consumed message with id: 682ac29e-61c2-471a-bfea-07678deda19d!
# Data inserted into table HH_vacancies
# Consumed message with id: 39b2984a-272e-4a1f-ab36-297785cfc31e!
# Data inserted into table HH_vacancies
# Consumed message with id: e022b39d-4c34-40c1-81a8-213cf51c357c!
# Data inserted into table HH_vacancies
# Consumed message with id: 2089cfed-6511-447f-9eff-7a7e7f8ea031!
# Data inserted into table HH_vacancies
# Consumed message with id: c3ed0656-dfe5-4466-8eed-5651b490569f!
# Data inserted into table HH_vacancies
# Consumed message with id: 0285f0c8-8074-476d-903c-5a3ba86eedd6!
# Data inserted into table HH_vacancies
# Consumed message with id: 4fbac522-605e-4fc0-aefb-c6502016ba7a!
# Data inserted into table HH_vacancies
# Consumed message with id: b40830dc-1028-49f2-85f6-f90ff1240452!
# Data inserted into table HH_vacancies
# Consumed message with id: 9be8ef9d-f8f3-4d05-a5ef-813303dfae33!
# Data inserted into table HH_vacancies
# Consumed message with id: b60dc3e2-722c-46f6-9faa-0d19ae14e916!
# Data inserted into table HH_vacancies
# Consumed message with id: da628ca7-31ae-462e-876d-0244be0108db!
# Data inserted into table HH_vacancies
# Consumed message with id: a6a253e0-32f8-4a5f-80aa-5d82cc0ff13b!
# Data inserted into table HH_vacancies
# Consumed message with id: 5c1fc905-39c2-4b60-a076-8d27abf61d5d!
# Data inserted into table HH_vacancies
# Consumed message with id: 85cf3fcd-2335-4681-99dd-a939306e9766!
# Data inserted into table HH_vacancies
# Consumed message with id: 2bbb2565-6f46-4896-908b-2f17c37e85ca!
# Data inserted into table HH_vacancies
# Consumed message with id: f604e68c-1bcb-4612-881c-c94135061449!
# Data inserted into table HH_vacancies
# Consumed message with id: 482c6655-5d22-4d0e-9556-3619eefa685f!
# Data inserted into table HH_vacancies
# Consumed message with id: 87dae318-d391-4b26-aac2-4f686b2e2d1a!
# Data inserted into table HH_vacancies
# Consumed message with id: 3c76f905-63fc-43ad-bac9-5d489a07159b!
# Data inserted into table HH_vacancies
# Consumed message with id: a3b7419e-89d0-437b-ba5f-596263106adb!
# Data inserted into table HH_vacancies
# Consumed message with id: baac9d2e-2b0c-4cfc-b9f3-9b9938842d14!
# Data inserted into table HH_vacancies
# Consumed message with id: 6b1bf494-0ce1-4a07-a5ad-12dad26a60af!
# Data inserted into table HH_vacancies
# Consumed message with id: e56e7411-6d2e-4d94-a657-46578c5e2186!
# Data inserted into table HH_vacancies
# Closed consumer!
